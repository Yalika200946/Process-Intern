# %% [markdown]
# # 06 — Cleaning Event Validation
#
# **Production status:** NOT IMPLEMENTED (placeholder created 2026-07-17)
#
# **Purpose:** Visual/human review of detected cleaning events (shell switch, TAM,
# unexplained recovery) so an engineer can confirm or reject each candidate before
# it is trusted downstream. Not the detection logic itself.
#
# **Inputs (planned):** `Data/Cleaning_Events.csv`, `dashboard/data/cleaning_history.json`
# (both produced by `pipeline/export_cleaning_history.py` — calculation-only, stays a
# `.py` script per the project's own rule that pure-calculation steps with no visual
# analysis do not need a dedicated notebook).
#
# **Outputs (planned):** none yet — read-only review notebook, no file writes.
#
# **Upstream dependency:** `pipeline/export_cleaning_history.py` (event_status/
# event_confidence taxonomy, see `docs/MIGRATION_MAP.md` and
# `docs/UNRESOLVED_ENGINEERING_DECISIONS.md` §5.0).
#
# **Downstream consumers:** none yet.
#
# **Known limitations:** empty placeholder — no analysis cells. Per
# `docs/UNRESOLVED_ENGINEERING_DECISIONS.md` §5, `CONFIRMED_CLEAN` cannot be
# promoted from `SWITCH_CANDIDATE` without an actual maintenance log; this notebook
# should surface that gap visually once authored, not paper over it.
