# %% [markdown]
# # Diagnostics — Event Detection
#
# **Production status:** NOT IMPLEMENTED (placeholder created 2026-07-17)
#
# **Purpose:** Diagnose the cleaning-event detection logic itself (shell-switch
# vs. TAM vs. unexplained-recovery classification) — e.g. false-positive/negative
# review, threshold sensitivity, confidence-tier distribution — separate from
# `notebooks/production/06_cleaning_event_validation.ipynb`'s per-event human
# review of individual results.
#
# **Inputs (planned):** `Data/Cleaning_Events.csv`, `pipeline/export_cleaning_history.py`
# (`event_confidence`/`event_status` functions), `src/domain/bypass.py`
# (`feasibility_label`).
#
# **Outputs (planned):** none yet — diagnostic only, not a source of truth for
# any dashboard value (per this project's rule that `diagnostics/` notebooks
# verify, they don't produce production artifacts).
#
# **Known limitations:** empty placeholder — no analysis cells.
